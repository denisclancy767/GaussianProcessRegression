# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# %%
merged = pd.read_csv('/content/gdrive/MyDrive/merged.csv')

# %%
merged = merged[merged['Energy (kWh)'] !=0]

# %%
merged = merged.reset_index()
merged
# Out:
#      index  Unnamed: 0                 Stop  Energy (kWh)  Total Units  \
# 0        0           0  2022-01-12 19:00:00    970.705482           45
# 1        1           1  2022-01-13 07:00:00   1955.644445           59
# 2        2           2  2022-01-13 19:00:00   2005.026689           55
# 3        3           3  2022-01-14 07:00:00   2085.867077           63
# 4        4           4  2022-01-14 19:00:00   1206.358962            0
# ..     ...         ...                  ...           ...          ...
# 286    432         432  2022-08-16 19:00:00   1856.476262           52
# 287    433         433  2022-08-17 07:00:00   1611.125946           16
# 288    434         434  2022-08-17 19:00:00   1895.134974           49
# 289    435         435  2022-08-18 07:00:00   1190.483930            0
# 290    436         436  2022-08-18 19:00:00    493.792162            0
#
#      Parts successful  Parts scrapped  Scrap pc
# 0                  45               0  0.000000
# 1                  58               1  1.694915
# 2                  55               0  0.000000
# 3                  63               0  0.000000
# 4                   0               0  0.000000
# ..                ...             ...       ...
# 286                52               0  0.000000
# 287                16               0  0.000000
# 288                46               3  6.122449
# 289                 0               0  0.000000
# 290                 0               0  0.000000
#
# [291 rows x 8 columns]

# %%
kernel = 1 * RBF(length_scale=1.0, length_scale_bounds=(1e-2, 1e2))
gaussian_process = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=1000)

# %%
stop = merged.iloc[:]['Stop']
stop = np.array(stop).reshape(-1,1)
energy = merged.iloc[:]['Energy (kWh)']
energy = np.array(energy).reshape(-1,1)
total = merged.iloc[:]['Total Units']
total = np.array(total).reshape(-1,1)
success = merged.iloc[:]['Parts successful']
success = np.array(success).reshape(-1,1)
scrap = merged.iloc[:]['Parts scrapped']
scrap = np.array(scrap).reshape(-1,1)

# %%
rng = np.random.RandomState(1)
training_indices = rng.choice(np.arange(energy.size), size=6, replace=False)
X_train, y_train = np.array(total[training_indices]).reshape(-1,1), np.array(energy[training_indices]).reshape(-1,1)

# %%
gaussian_process.fit(total,energy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/_gpr.py:629: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# GaussianProcessRegressor(kernel=1**2 * RBF(length_scale=1),
#                          n_restarts_optimizer=1000)

# %%
plt.plot(total,energy,'o')
#plt.plot(X_train,y_train)

# %%
X = np.linspace(start=0, stop=100, num=10000).reshape(-1,1)
predict = gaussian_process.predict(X)
plt.plot(X,predict)

# %%
count = 0
len = predict.size
for i in range(len):
  if predict[i] == 0:
    count = count + 1
count
# Out:
# 4282

# %%
type(predict)
# Out:
# numpy.ndarray

# %%
idk = np.array(45).reshape(-1,1)
prediction = gaussian_process.predict(idk)
prediction
# Out:
# array([1792.])

# %%
X = np.linspace(start=0, stop=10, num=1_000).reshape(-1, 1)
d = 1;
X = X.reshape(437, d)
mean_prediction, std_prediction = gaussian_process.predict(X, return_std=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-174-cc24ff4bb4ed> in <cell line: 3>()
#       1 X = np.linspace(start=0, stop=10, num=1_000).reshape(-1, 1)
#       2 d = 1;
# ----> 3 X = X.reshape(437, d)
#       4 mean_prediction, std_prediction = gaussian_process.predict(X, return_std=True)
#
# ValueError: cannot reshape array of size 1000 into shape (437,1)

# %%
merged[~(merged == 0).all(axis=1)]
merged.iloc[13][2]
# Out:
# 0.0
